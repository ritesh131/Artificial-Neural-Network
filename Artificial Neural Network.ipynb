# %% [markdown]
# ### Artificial Neural Network using Keras

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'DataSet/data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# compactness_se             569 non-null float64
# concavity_se               569 non-null float64
# concave points_se          569 non-null float64
# symmetry_se                569 non-null float64
# fractal_dimension_se       569 non-null float64
# radius_worst               569 non-null float64
# texture_worst              569 non-null float64
# perimeter_worst            569 non-null float64
# area_worst                 569 non-null float64
# smoothness_worst           569 non-null float64
# compactness_worst          569 non-null float64
# concavity_worst            569 non-null float64
# concave points_worst       569 non-null float64
# symmetry_worst             569 non-null float64
# fractal_dimension_worst    569 non-null float64
# Unnamed: 32                0 non-null float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
data.hist(bins=50,figsize=(20,15))
plt.show()

# %%
ax = sns.countplot(data['diagnosis'], label='Count')
B, M = data['diagnosis'].value_counts()
print('Benign', B)
print('Malignanat', M)
# Out:
# Benign 357
# Malignanat 212

# %%
del data['Unnamed: 32']
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Data PreProsesing

# %%
X = data.iloc[:, 2:].values
y = data.iloc[:, 1].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y = labelencoder_X_1.fit_transform(y)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Import all require library to build ANN Model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(output_dim=16, init='uniform', activation='relu', input_dim=30))
# Adding dropout to prevent overfitting
classifier.add(Dropout(p=0.1))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=30, units=16, kernel_initializer="uniform")`
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(rate=0.1)`
#   after removing the cwd from sys.path.

# %%
# Adding the second hidden layer
classifier.add(Dense(output_dim=16, init='uniform', activation='relu'))
# Adding dropout to prevent overfitting
classifier.add(Dropout(p=0.1))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=16, kernel_initializer="uniform")`
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(rate=0.1)`
#   after removing the cwd from sys.path.

# %%
# Adding the output layer
classifier.add(Dense(output_dim=1, init='uniform', activation='sigmoid'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`

# %%
# Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size=100, nb_epoch=150)
# Long scroll ahead but worth
# The batch size and number of epochs have been set using trial and error. Still looking for more efficient ways. Open to suggestions.
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/150
# 512/512 [==============================] - 0s 890us/step - loss: 0.6924 - accuracy: 0.6797
# Epoch 2/150
# 512/512 [==============================] - 0s 41us/step - loss: 0.6901 - accuracy: 0.7109
# Epoch 3/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.6863 - accuracy: 0.7812
# Epoch 4/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.6802 - accuracy: 0.8574
# Epoch 5/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.6705 - accuracy: 0.9043
# Epoch 6/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.6565 - accuracy: 0.9238
# Epoch 7/150
# 512/512 [==============================] - 0s 51us/step - loss: 0.6362 - accuracy: 0.9316
# Epoch 8/150
# 512/512 [==============================] - 0s 45us/step - loss: 0.6076 - accuracy: 0.9316
# Epoch 9/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.5720 - accuracy: 0.9375
# Epoch 10/150
# 512/512 [==============================] - 0s 43us/step - loss: 0.5255 - accuracy: 0.9336
# Epoch 11/150
# 512/512 [==============================] - 0s 43us/step - loss: 0.4765 - accuracy: 0.9375
# Epoch 12/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.4213 - accuracy: 0.9355
# Epoch 13/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.3662 - accuracy: 0.9375
# Epoch 14/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.3226 - accuracy: 0.9414
# Epoch 15/150
# 512/512 [==============================] - 0s 45us/step - loss: 0.2793 - accuracy: 0.9434
# Epoch 16/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.2415 - accuracy: 0.9492
# Epoch 17/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.2141 - accuracy: 0.9512
# Epoch 18/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.1934 - accuracy: 0.9531
# Epoch 19/150
# 512/512 [==============================] - 0s 36us/step - loss: 0.1770 - accuracy: 0.9629
# Epoch 20/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.1595 - accuracy: 0.9590
# Epoch 21/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.1490 - accuracy: 0.9668
# Epoch 22/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.1379 - accuracy: 0.9668
# Epoch 23/150
# 512/512 [==============================] - 0s 41us/step - loss: 0.1265 - accuracy: 0.9688
# Epoch 24/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.1150 - accuracy: 0.9727
# Epoch 25/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.1147 - accuracy: 0.9727
# Epoch 26/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.1082 - accuracy: 0.9746
# Epoch 27/150
# 512/512 [==============================] - 0s 47us/step - loss: 0.1021 - accuracy: 0.9746
# Epoch 28/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0973 - accuracy: 0.9746
# Epoch 29/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0964 - accuracy: 0.9766
# Epoch 30/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0964 - accuracy: 0.9785
# Epoch 31/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0933 - accuracy: 0.9746
# Epoch 32/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0918 - accuracy: 0.9746
# Epoch 33/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0853 - accuracy: 0.9824
# Epoch 34/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0853 - accuracy: 0.9805
# Epoch 35/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0825 - accuracy: 0.9844
# Epoch 36/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0838 - accuracy: 0.9824
# Epoch 37/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0826 - accuracy: 0.9805
# Epoch 38/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.0812 - accuracy: 0.9824
# Epoch 39/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0730 - accuracy: 0.9844
# Epoch 40/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0770 - accuracy: 0.9844
# Epoch 41/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0751 - accuracy: 0.9863
# Epoch 42/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0722 - accuracy: 0.9863
# Epoch 43/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0750 - accuracy: 0.9824
# Epoch 44/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0679 - accuracy: 0.9863
# Epoch 45/150
# 512/512 [==============================] - 0s 45us/step - loss: 0.0706 - accuracy: 0.9844
# Epoch 46/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0644 - accuracy: 0.9824
# Epoch 47/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.0671 - accuracy: 0.9844
# Epoch 48/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.0656 - accuracy: 0.9844
# Epoch 49/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0687 - accuracy: 0.9844
# Epoch 50/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0641 - accuracy: 0.9844
# Epoch 51/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0686 - accuracy: 0.9863
# Epoch 52/150
# 512/512 [==============================] - 0s 38us/step - loss: 0.0624 - accuracy: 0.9844
# Epoch 53/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0635 - accuracy: 0.9863
# Epoch 54/150
# 512/512 [==============================] - 0s 43us/step - loss: 0.0609 - accuracy: 0.9844
# Epoch 55/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0646 - accuracy: 0.9844
# Epoch 56/150
# 512/512 [==============================] - 0s 51us/step - loss: 0.0596 - accuracy: 0.9863
# Epoch 57/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0653 - accuracy: 0.9844
# Epoch 58/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.0585 - accuracy: 0.9844
# Epoch 59/150
# 512/512 [==============================] - 0s 41us/step - loss: 0.0605 - accuracy: 0.9844
# Epoch 60/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0598 - accuracy: 0.9844
# Epoch 61/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0575 - accuracy: 0.9863
# Epoch 62/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0593 - accuracy: 0.9844
# Epoch 63/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.0575 - accuracy: 0.9863
# Epoch 64/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0623 - accuracy: 0.9824
# Epoch 65/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0547 - accuracy: 0.9844
# Epoch 66/150
# 512/512 [==============================] - 0s 41us/step - loss: 0.0572 - accuracy: 0.9844
# Epoch 67/150
# 512/512 [==============================] - 0s 57us/step - loss: 0.0621 - accuracy: 0.9863
# Epoch 68/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0590 - accuracy: 0.9863
# Epoch 69/150
# 512/512 [==============================] - 0s 38us/step - loss: 0.0603 - accuracy: 0.9844
# Epoch 70/150
# 512/512 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.99 - 0s 33us/step - loss: 0.0591 - accuracy: 0.9844
# Epoch 71/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0584 - accuracy: 0.9863
# Epoch 72/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.0548 - accuracy: 0.9863
# Epoch 73/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0587 - accuracy: 0.9863
# Epoch 74/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0539 - accuracy: 0.9863
# Epoch 75/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0529 - accuracy: 0.9863
# Epoch 76/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0501 - accuracy: 0.9863
# Epoch 77/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0501 - accuracy: 0.9863
# Epoch 78/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0508 - accuracy: 0.9844
# Epoch 79/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0501 - accuracy: 0.9844
# Epoch 80/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0519 - accuracy: 0.9863
# Epoch 81/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0545 - accuracy: 0.9844
# Epoch 82/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0510 - accuracy: 0.9844
# Epoch 83/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0543 - accuracy: 0.9863
# Epoch 84/150
# 512/512 [==============================] - 0s 23us/step - loss: 0.0516 - accuracy: 0.9863
# Epoch 85/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0482 - accuracy: 0.9863
# Epoch 86/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0522 - accuracy: 0.9863
# Epoch 87/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0521 - accuracy: 0.9844
# Epoch 88/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0514 - accuracy: 0.9863
# Epoch 89/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0479 - accuracy: 0.9863
# Epoch 90/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0514 - accuracy: 0.9883
# Epoch 91/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0493 - accuracy: 0.9863
# Epoch 92/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0484 - accuracy: 0.9883
# Epoch 93/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0508 - accuracy: 0.9824
# Epoch 94/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0466 - accuracy: 0.9883
# Epoch 95/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0488 - accuracy: 0.9863
# Epoch 96/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0503 - accuracy: 0.9883
# Epoch 97/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0483 - accuracy: 0.9883
# Epoch 98/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0490 - accuracy: 0.9883
# Epoch 99/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0503 - accuracy: 0.9863
# Epoch 100/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0507 - accuracy: 0.9883
# Epoch 101/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0469 - accuracy: 0.9883
# Epoch 102/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0459 - accuracy: 0.9902
# Epoch 103/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0425 - accuracy: 0.9883
# Epoch 104/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0435 - accuracy: 0.9883
# Epoch 105/150
# 512/512 [==============================] - 0s 23us/step - loss: 0.0448 - accuracy: 0.9883
# Epoch 106/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0467 - accuracy: 0.9883
# Epoch 107/150
# 512/512 [==============================] - 0s 23us/step - loss: 0.0452 - accuracy: 0.9902
# Epoch 108/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0489 - accuracy: 0.9902
# Epoch 109/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0462 - accuracy: 0.9883
# Epoch 110/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0459 - accuracy: 0.9883
# Epoch 111/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0466 - accuracy: 0.9863
# Epoch 112/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0429 - accuracy: 0.9902
# Epoch 113/150
# 512/512 [==============================] - 0s 39us/step - loss: 0.0440 - accuracy: 0.9883
# Epoch 114/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0426 - accuracy: 0.9883
# Epoch 115/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0448 - accuracy: 0.9863
# Epoch 116/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0456 - accuracy: 0.9902
# Epoch 117/150
# 512/512 [==============================] - 0s 23us/step - loss: 0.0460 - accuracy: 0.9883
# Epoch 118/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0431 - accuracy: 0.9883
# Epoch 119/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0464 - accuracy: 0.9883
# Epoch 120/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0400 - accuracy: 0.9902
# Epoch 121/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0452 - accuracy: 0.9883
# Epoch 122/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0413 - accuracy: 0.9902
# Epoch 123/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0449 - accuracy: 0.9902
# Epoch 124/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0425 - accuracy: 0.9883
# Epoch 125/150
# 512/512 [==============================] - 0s 41us/step - loss: 0.0434 - accuracy: 0.9902
# Epoch 126/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0462 - accuracy: 0.9902
# Epoch 127/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0417 - accuracy: 0.9902
# Epoch 128/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0442 - accuracy: 0.9902
# Epoch 129/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0447 - accuracy: 0.9902
# Epoch 130/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0462 - accuracy: 0.9844
# Epoch 131/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0459 - accuracy: 0.9902
# Epoch 132/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0408 - accuracy: 0.9902
# Epoch 133/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0455 - accuracy: 0.9902
# Epoch 134/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0424 - accuracy: 0.9902
# Epoch 135/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0438 - accuracy: 0.9902
# Epoch 136/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0395 - accuracy: 0.9902
# Epoch 137/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0424 - accuracy: 0.9902
# Epoch 138/150
# 512/512 [==============================] - 0s 25us/step - loss: 0.0445 - accuracy: 0.9883
# Epoch 139/150
# 512/512 [==============================] - 0s 27us/step - loss: 0.0376 - accuracy: 0.9902
# Epoch 140/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0406 - accuracy: 0.9922
# Epoch 141/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0438 - accuracy: 0.9902
# Epoch 142/150
# 512/512 [==============================] - 0s 31us/step - loss: 0.0410 - accuracy: 0.9902
# Epoch 143/150
# 512/512 [==============================] - 0s 37us/step - loss: 0.0408 - accuracy: 0.9883
# Epoch 144/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0422 - accuracy: 0.9902
# Epoch 145/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0402 - accuracy: 0.9902
# Epoch 146/150
# 512/512 [==============================] - 0s 29us/step - loss: 0.0366 - accuracy: 0.9922
# Epoch 147/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0394 - accuracy: 0.9922
# Epoch 148/150
# 512/512 [==============================] - 0s 35us/step - loss: 0.0347 - accuracy: 0.9922
# Epoch 149/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0383 - accuracy: 0.9902
# Epoch 150/150
# 512/512 [==============================] - 0s 33us/step - loss: 0.0371 - accuracy: 0.9902

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
print("Our accuracy is {}%".format(((cm[0][0] + cm[1][1])/57)*100))
# Out:
# Our accuracy is 100.0%

# %%
sns.heatmap(cm,annot=True)
plt.savefig('h.png')
